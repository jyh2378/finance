# %%
import os
import math
import datetime
import string
import time
import random
from glob import glob
import importlib
import random

import numpy as np
import pandas as pd
import yfinance as yf
import yahooquery as yq

from utils import *
import fundamental.analysis

importlib.reload(fundamental.analysis)

# db = fundamental.analysis.Database("DB/250531")
# db = fundamental.analysis.Database("DB/250524")
db = fundamental.analysis.Database()
# Out:
# Loading database from 250628...

# %%
db.value_summary.loc["SRPT"]
# Out:
# Market Cap                                                            1681519488.0
# Sector                                                                  Healthcare
# Industry                                                             Biotechnology
# Long Business Summary            Sarepta Therapeutics, Inc., a commercial-stage...
# Price                                                                    17.110001
# Simple Forward PER Fair Price                                           -34.751419
# Forward PEGR Fair Price                                                        NaN
# Name: SRPT, dtype: object

# %%
db.get_forward_eps().loc["SRPT"]
# Out:
# Fiscal Period
# 2025-12-31    0.10375
# 2026-12-31    7.84696
# Name: EPS Estimate, dtype: float64

# %%
db.get_forward_eps().loc["SRPT"]
# Out:
# Fiscal Period
# 2025-12-31   -1.8860
# 2026-12-31    3.6502
# Name: EPS Estimate, dtype: float64

# %%
db.calc_simple_fper_valuation(1).loc["SRPT"]
# Out:
# Sector                    Healthcare
# Industry               Biotechnology
# Price                          36.18
# Forward EPS                  7.84696
# Forward PER                 4.610703
# Forward PER(Sector)        15.803517
# Fair Price                124.009565
# Name: SRPT, dtype: object

# %%
db.get_forward_eps_growth_rate().loc["SRPT"]
# Out:
# Fiscal Period
# 2025-12-31    -0.9719
# 2026-12-31    74.6333
# Name: EPS YoY Growth, dtype: float64

# %%
db.get_forward_eps().loc["SRPT"]
# Out:
# Fiscal Period
# 2025-12-31    0.10375
# 2026-12-31    7.84696
# Name: EPS Estimate, dtype: float64
